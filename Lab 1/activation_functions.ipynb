# %% [markdown]
# # Activation Functions

# %%
# %pip install torch torchvision
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys; print(sys.executable)
# Out:
# C:\Users\esgue\anaconda3\envs\sc4001\python.exe

# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
    
print(torch.__version__)
# Out:
# 2.14.0+cpu

# %%
# inputs for ploting activation functions
u = torch.arange(-10.0, 10.0, 0.1)

# %% [markdown]
# # Threshold activation
#
# ###  $thresh(u)=1(u>0)$

# %%
def threshold(u):
	return (u>0.0).float()

# %%
# thresh
y = threshold(u)

# %%
plt.figure()
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))
plt.xticks([-5, 5])
plt.yticks([0.5, 1.0])
plt.plot(u.numpy(),y.numpy())
plt.xlabel('$u$')
plt.title('thresh($u$)')
plt.show()

# %% [markdown]
# # Sigmoid activation
#
# ### $sigmoid(u) = \frac{1}{1+ e^{-u}}$

# %%
# sigmoid
y = torch.sigmoid(u)

# %%
plt.figure()
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))
plt.xticks([-5, 5])
plt.yticks([0.5, 1.0])
plt.plot(u.numpy(),y.numpy())
plt.xlabel('$u$')
plt.title('sigmoid($u$)')
plt.show()

# %% [markdown]
# # Linear activation
#
# ### $f(u) = u$

# %%
# linear
y = u

# %%
plt.figure()
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))
plt.xticks([-5, 5])
plt.yticks([-5, 5])
plt.plot(u.numpy(),y.numpy())
# pylab.xlabel('$u$')
plt.title('linear($u$)')
plt.show()

# %% [markdown]
# # ReLU activation
#
# ### $ReLU(u) = \max\{0, u\}$

# %%
# relu
f = nn.ReLU()
y = f(u)

# %%
plt.figure()
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))
plt.xticks([-5, 5])
plt.yticks([5])
plt.plot(u.numpy(),y.numpy())
plt.xlabel('$u$')
plt.title('ReLU($u$)')
plt.show()

# %% [markdown]
# # Tanh activation
#
# ### $tanh(u) = \frac{e^u - e^{-u}}{e^u + e^{-u}}$

# %%
# tanh
y = torch.tanh(u)

# %%
plt.figure()
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))
plt.xticks([-5,  5])
plt.yticks([-1.0, -0.5, 0.5, 1.0])
plt.plot(u.numpy(),y.numpy())
# pylab.xlabel('$u$')
plt.title('tanh($u$)')
plt.show()
