# %% [markdown]
# # Example 4.5: Classification of MNIST data

# %%
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor

# %%
# Set random seed for reproducibility
SEED = 10
torch.manual_seed(SEED)

# %%
# read the data from torchvision.datasets
training_data = datasets.FashionMNIST(
    root="data",
    train=True,
    download=True,
    transform=ToTensor()
)

test_data = datasets.FashionMNIST(
    root="data",
    train=False,
    download=True,
    transform=ToTensor()
)

# load the data using dataloaders
train_dataloader = DataLoader(training_data, batch_size=64, shuffle=True)
test_dataloader = DataLoader(test_data, batch_size=64, shuffle=False)

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        self.softmax_relu_stack = nn.Sequential(
            nn.Linear(28*28, 512),
            nn.ReLU(),
            nn.Linear(512, 512),
            nn.ReLU(),
            nn.Linear(512, 10)
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.softmax_relu_stack(x)
        return logits

model = NeuralNetwork()

# %% [markdown]
# ## Hyperparameters
#
# Hyperparameters are adjustable parameters that let you control the model optimization process.
# Different hyperparameter values can impact model training and convergence rates
# ([read more](https://pytorch.org/tutorials/beginner/hyperparameter_tuning_tutorial.html)_ about hyperparameter tuning)
#
# We define the following hyperparameters for training:
#  - **Number of Epochs** - the number times to iterate over the dataset
#  - **Batch Size** - the number of data samples propagated through the network before the parameters are updated
#  - **Learning Rate** - how much to update models parameters at each batch/epoch. Smaller values yield slow learning speed, while large values may result in unpredictable behavior during training.

# %%
learning_rate = 1e-2
batch_size = 64
epochs = 100

# %% [markdown]
# ## Optimization Loop
#
# Once we set our hyperparameters, we can then train and optimize our model with an optimization loop. Each
# iteration of the optimization loop is called an **epoch**.
#
# Each epoch consists of two main parts:
#  - **The Train Loop** - iterate over the training dataset and try to converge to optimal parameters.
#  - **The Validation/Test Loop** - iterate over the test dataset to check if model performance is improving.
#
# Let's briefly familiarize ourselves with some of the concepts used in the training loop. Jump ahead to
# see the `full-impl-label` of the optimization loop.
#
# ### Loss Function
#
# When presented with some training data, our untrained network is likely not to give the correct
# answer. **Loss function** measures the degree of dissimilarity of obtained result to the target value,
# and it is the loss function that we want to minimize during training. To calculate the loss we make a
# prediction using the inputs of our given data sample and compare it against the true data label value.
#
# Common loss functions include [nn.MSELoss](https://pytorch.org/docs/stable/generated/torch.nn.MSELoss.html#torch.nn.MSELoss) (Mean Square Error) for regression tasks, and
# [nn.NLLLoss](https://pytorch.org/docs/stable/generated/torch.nn.NLLLoss.html#torch.nn.NLLLoss) (Negative Log Likelihood) for classification.
# [nn.CrossEntropyLoss](https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html#torch.nn.CrossEntropyLoss) combines ``nn.LogSoftmax`` and ``nn.NLLLoss``.
#
# We pass our model's output logits to ``nn.CrossEntropyLoss``, which will normalize the logits and compute the prediction error.

# %%
# Initialize the loss function
loss_fn = nn.CrossEntropyLoss(reduction='sum')

# %% [markdown]
# ### Optimizer
#
# Optimization is the process of adjusting model parameters to reduce model error in each training step. **Optimization algorithms** define how this process is performed (in this example we use Stochastic Gradient Descent).
# All optimization logic is encapsulated in  the ``optimizer`` object. Here, we use the SGD optimizer; additionally, there are many [different optimizers](https://pytorch.org/docs/stable/optim.html)
# available in PyTorch such as ADAM and RMSProp, that work better for different kinds of models and data.
#
# We initialize the optimizer by registering the model's parameters that need to be trained, and passing in the learning rate hyperparameter.

# %%
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

# %% [markdown]
# Inside the training loop, optimization happens in three steps:
#  * Call ``optimizer.zero_grad()`` to reset the gradients of model parameters. Gradients by default add up; to prevent double-counting, we explicitly zero them at each iteration.
#  * Backpropagate the prediction loss with a call to ``loss.backward()``. PyTorch deposits the gradients of the loss w.r.t. each parameter.
#  * Once we have our gradients, we call ``optimizer.step()`` to adjust the parameters by the gradients collected in the backward pass.

# %% [markdown]
# ## Full Implementation
# We define ``train_loop`` that loops over our optimization code, and ``test_loop`` that
# evaluates the model's performance against our test data.

# %%
def train_loop(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    train_loss, correct = 0, 0
    for batch, (X, y) in enumerate(dataloader):
        # Compute prediction and loss
        pred = model(X)
        loss = loss_fn(pred, y)
        
        train_loss += loss.item()
        correct += (pred.argmax(1) == y).type(torch.float).sum().item()

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if batch % 100 == 0:
            loss, current = loss.item(), (batch + 1) * len(X)
            print(f"loss: {loss:>7f}  [{current:>5d}/{size:>5d}]")
    
    train_loss /= size
    correct /= size
    print(f"Train Error: \n Accuracy: {(correct*100):>0.1f}%, Avg loss: {train_loss:>8f} \n")
    
    return train_loss, correct

def test_loop(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    test_loss, correct = 0, 0

    with torch.no_grad():
        for X, y in dataloader:
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()

    test_loss /= size
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")
    
    return test_loss, correct

# %% [markdown]
# We initialize the loss function and optimizer, and pass it to ``train_loop`` and ``test_loop``.
# Feel free to increase the number of epochs to track the model's improving performance.

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)

train_loss, test_loss = [], []
train_acc, test_acc = [], []
for t in range(epochs):
    print(f"Epoch {t+1}\n-------------------------------")
    loss, acc = train_loop(train_dataloader, model, loss_fn, optimizer)
    train_loss.append(loss), train_acc.append(acc)
    
    loss, acc = test_loop(test_dataloader, model, loss_fn)
    test_loss.append(loss), test_acc.append(acc)
print("Done!")
# Out:
# Epoch 1
# -------------------------------
# loss: 2.315814  [   64/60000]
# loss: 2.172022  [ 6464/60000]
# loss: 1.840250  [12864/60000]
# loss: 1.448035  [19264/60000]
# loss: 1.167949  [25664/60000]
# loss: 1.097603  [32064/60000]
# loss: 0.987264  [38464/60000]
# loss: 0.894556  [44864/60000]
# loss: 0.820415  [51264/60000]
# loss: 0.874756  [57664/60000]
# Train Error:
#  Accuracy: 59.6%, Avg loss: 0.020445
#
# Test Error:
#  Accuracy: 70.1%, Avg loss: 0.012537
#
# Epoch 2
# -------------------------------
# loss: 0.837926  [   64/60000]
# loss: 0.746889  [ 6464/60000]
# loss: 0.663557  [12864/60000]
# loss: 0.713777  [19264/60000]
# loss: 0.686699  [25664/60000]
# loss: 0.765362  [32064/60000]
# loss: 0.614002  [38464/60000]
# loss: 0.645593  [44864/60000]
# loss: 0.764680  [51264/60000]
# loss: 0.626569  [57664/60000]
# Train Error:
#  Accuracy: 75.8%, Avg loss: 0.010715
#
# Test Error:
#  Accuracy: 78.7%, Avg loss: 0.009827
#
# Epoch 3
# -------------------------------
# loss: 0.561024  [   64/60000]
# loss: 0.615015  [ 6464/60000]
# loss: 0.700809  [12864/60000]
# loss: 0.661843  [19264/60000]
# loss: 0.587276  [25664/60000]
# loss: 0.678050  [32064/60000]
# loss: 0.551211  [38464/60000]
# loss: 0.362614  [44864/60000]
# loss: 0.468183  [51264/60000]
# loss: 0.522518  [57664/60000]
# Train Error:
#  Accuracy: 80.5%, Avg loss: 0.008899
#
# Test Error:
#  Accuracy: 80.8%, Avg loss: 0.008687
#
# Epoch 4
# -------------------------------
# loss: 0.491024  [   64/60000]
# loss: 0.623787  [ 6464/60000]
# loss: 0.490907  [12864/60000]
# loss: 0.641420  [19264/60000]
# loss: 0.550051  [25664/60000]
# loss: 0.389453  [32064/60000]
# loss: 0.558787  [38464/60000]
# loss: 0.320287  [44864/60000]
# loss: 0.468327  [51264/60000]
# loss: 0.507093  [57664/60000]
# Train Error:
#  Accuracy: 82.2%, Avg loss: 0.008042
#
# Test Error:
#  Accuracy: 80.0%, Avg loss: 0.008688
#
# Epoch 5
# -------------------------------
# loss: 0.526689  [   64/60000]
# loss: 0.387781  [ 6464/60000]
# loss: 0.412270  [12864/60000]
# loss: 0.308092  [19264/60000]
# loss: 0.458291  [25664/60000]
# loss: 0.375934  [32064/60000]
# loss: 0.457594  [38464/60000]
# loss: 0.436415  [44864/60000]
# loss: 0.431552  [51264/60000]
# loss: 0.362137  [57664/60000]
# Train Error:
#  Accuracy: 83.0%, Avg loss: 0.007558
#
# Test Error:
#  Accuracy: 82.4%, Avg loss: 0.007753
#
# Epoch 6
# -------------------------------
# loss: 0.558088  [   64/60000]
# loss: 0.548555  [ 6464/60000]
# loss: 0.415530  [12864/60000]
# loss: 0.582725  [19264/60000]
# loss: 0.436269  [25664/60000]
# loss: 0.449196  [32064/60000]
# loss: 0.294499  [38464/60000]
# loss: 0.514791  [44864/60000]
# loss: 0.387811  [51264/60000]
# loss: 0.457222  [57664/60000]
# Train Error:
#  Accuracy: 83.8%, Avg loss: 0.007237
#
# Test Error:
#  Accuracy: 82.9%, Avg loss: 0.007554
#
# Epoch 7
# -------------------------------
# loss: 0.370094  [   64/60000]
# loss: 0.403886  [ 6464/60000]
# loss: 0.401219  [12864/60000]
# loss: 0.511466  [19264/60000]
# loss: 0.613292  [25664/60000]
# loss: 0.358275  [32064/60000]
# loss: 0.450377  [38464/60000]
# loss: 0.436045  [44864/60000]
# loss: 0.401438  [51264/60000]
# loss: 0.407892  [57664/60000]
# Train Error:
#  Accuracy: 84.3%, Avg loss: 0.006992
#
# Test Error:
#  Accuracy: 82.1%, Avg loss: 0.007619
#
# Epoch 8
# -------------------------------
# loss: 0.557345  [   64/60000]
# loss: 0.532885  [ 6464/60000]
# loss: 0.427234  [12864/60000]
# loss: 0.615693  [19264/60000]
# loss: 0.704380  [25664/60000]
# loss: 0.474838  [32064/60000]
# loss: 0.354592  [38464/60000]
# loss: 0.330553  [44864/60000]
# loss: 0.526923  [51264/60000]
# loss: 0.336450  [57664/60000]
# Train Error:
#  Accuracy: 84.8%, Avg loss: 0.006797
#
# Test Error:
#  Accuracy: 83.3%, Avg loss: 0.007401
#
# Epoch 9
# -------------------------------
# loss: 0.500983  [   64/60000]
# loss: 0.472329  [ 6464/60000]
# loss: 0.681884  [12864/60000]
# loss: 0.537584  [19264/60000]
# loss: 0.413624  [25664/60000]
# loss: 0.652014  [32064/60000]
# loss: 0.362444  [38464/60000]
# loss: 0.446538  [44864/60000]
# loss: 0.240560  [51264/60000]
# loss: 0.364702  [57664/60000]
# Train Error:
#  Accuracy: 85.2%, Avg loss: 0.006631
#
# Test Error:
#  Accuracy: 84.0%, Avg loss: 0.007002
#
# Epoch 10
# -------------------------------
# loss: 0.460629  [   64/60000]
# loss: 0.518266  [ 6464/60000]
# loss: 0.384182  [12864/60000]
# loss: 0.411551  [19264/60000]
# loss: 0.423507  [25664/60000]
# loss: 0.276733  [32064/60000]
# loss: 0.392477  [38464/60000]
# loss: 0.491676  [44864/60000]
# loss: 0.297281  [51264/60000]
# loss: 0.369194  [57664/60000]
# Train Error:
#  Accuracy: 85.5%, Avg loss: 0.006475
#
# Test Error:
#  Accuracy: 84.3%, Avg loss: 0.006876
#
# Epoch 11
# -------------------------------
# loss: 0.462639  [   64/60000]
# loss: 0.259492  [ 6464/60000]
# loss: 0.443192  [12864/60000]
# loss: 0.541840  [19264/60000]
# loss: 0.420287  [25664/60000]
# loss: 0.365250  [32064/60000]
# loss: 0.466921  [38464/60000]
# loss: 0.403645  [44864/60000]
# loss: 0.409767  [51264/60000]
# loss: 0.335058  [57664/60000]
# Train Error:
#  Accuracy: 85.9%, Avg loss: 0.006327
#
# Test Error:
#  Accuracy: 84.4%, Avg loss: 0.006871
#
# Epoch 12
# -------------------------------
# loss: 0.373516  [   64/60000]
# loss: 0.373840  [ 6464/60000]
# loss: 0.333950  [12864/60000]
# loss: 0.454514  [19264/60000]
# loss: 0.381183  [25664/60000]
# loss: 0.375935  [32064/60000]
# loss: 0.468929  [38464/60000]
# loss: 0.439549  [44864/60000]
# loss: 0.325925  [51264/60000]
# loss: 0.507456  [57664/60000]
# Train Error:
#  Accuracy: 86.1%, Avg loss: 0.006216
#
# Test Error:
#  Accuracy: 84.7%, Avg loss: 0.006704
#
# Epoch 13
# -------------------------------
# loss: 0.350434  [   64/60000]
# loss: 0.554981  [ 6464/60000]
# loss: 0.445428  [12864/60000]
# loss: 0.385371  [19264/60000]
# loss: 0.414965  [25664/60000]
# loss: 0.346313  [32064/60000]
# loss: 0.330752  [38464/60000]
# loss: 0.420812  [44864/60000]
# loss: 0.190114  [51264/60000]
# loss: 0.347716  [57664/60000]
# Train Error:
#  Accuracy: 86.3%, Avg loss: 0.006100
#
# Test Error:
#  Accuracy: 84.6%, Avg loss: 0.006729
#
# Epoch 14
# -------------------------------
# loss: 0.328938  [   64/60000]
# loss: 0.415301  [ 6464/60000]
# loss: 0.416803  [12864/60000]
# loss: 0.428224  [19264/60000]
# loss: 0.401357  [25664/60000]
# loss: 0.453967  [32064/60000]
# loss: 0.467809  [38464/60000]
# loss: 0.425365  [44864/60000]
# loss: 0.404652  [51264/60000]
# loss: 0.489074  [57664/60000]
# Train Error:
#  Accuracy: 86.6%, Avg loss: 0.005986
#
# Test Error:
#  Accuracy: 85.4%, Avg loss: 0.006499
#
# Epoch 15
# -------------------------------
# loss: 0.475973  [   64/60000]
# loss: 0.274775  [ 6464/60000]
# loss: 0.350570  [12864/60000]
# loss: 0.317660  [19264/60000]
# loss: 0.411189  [25664/60000]
# loss: 0.384142  [32064/60000]
# loss: 0.366304  [38464/60000]
# loss: 0.382566  [44864/60000]
# loss: 0.377927  [51264/60000]
# loss: 0.265183  [57664/60000]
# Train Error:
#  Accuracy: 86.9%, Avg loss: 0.005897
#
# Test Error:
#  Accuracy: 84.1%, Avg loss: 0.006731
#
# Epoch 16
# -------------------------------
# loss: 0.429032  [   64/60000]
# loss: 0.421448  [ 6464/60000]
# loss: 0.282820  [12864/60000]
# loss: 0.408095  [19264/60000]
# loss: 0.372851  [25664/60000]
# loss: 0.323726  [32064/60000]
# loss: 0.406638  [38464/60000]
# loss: 0.416954  [44864/60000]
# loss: 0.388614  [51264/60000]
# loss: 0.594254  [57664/60000]
# Train Error:
#  Accuracy: 87.0%, Avg loss: 0.005794
#
# Test Error:
#  Accuracy: 85.4%, Avg loss: 0.006447
#
# Epoch 17
# -------------------------------
# loss: 0.598242  [   64/60000]
# loss: 0.415290  [ 6464/60000]
# loss: 0.653682  [12864/60000]
# loss: 0.203424  [19264/60000]
# loss: 0.391276  [25664/60000]
# loss: 0.175151  [32064/60000]
# loss: 0.340302  [38464/60000]
# loss: 0.355901  [44864/60000]
# loss: 0.449786  [51264/60000]
# loss: 0.442171  [57664/60000]
# Train Error:
#  Accuracy: 87.2%, Avg loss: 0.005719
#
# Test Error:
#  Accuracy: 83.9%, Avg loss: 0.006859
#
# Epoch 18
# -------------------------------
# loss: 0.398845  [   64/60000]
# loss: 0.496587  [ 6464/60000]
# loss: 0.410371  [12864/60000]
# loss: 0.461744  [19264/60000]
# loss: 0.386152  [25664/60000]
# loss: 0.291595  [32064/60000]
# loss: 0.313011  [38464/60000]
# loss: 0.428715  [44864/60000]
# loss: 0.375188  [51264/60000]
# loss: 0.291162  [57664/60000]
# Train Error:
#  Accuracy: 87.3%, Avg loss: 0.005632
#
# Test Error:
#  Accuracy: 85.3%, Avg loss: 0.006481
#
# Epoch 19
# -------------------------------
# loss: 0.341363  [   64/60000]
# loss: 0.466465  [ 6464/60000]
# loss: 0.336585  [12864/60000]
# loss: 0.320342  [19264/60000]
# loss: 0.299577  [25664/60000]
# loss: 0.268475  [32064/60000]
# loss: 0.253826  [38464/60000]
# loss: 0.452922  [44864/60000]
# loss: 0.331995  [51264/60000]
# loss: 0.320210  [57664/60000]
# Train Error:
#  Accuracy: 87.5%, Avg loss: 0.005535
#
# Test Error:
#  Accuracy: 85.5%, Avg loss: 0.006358
#
# Epoch 20
# -------------------------------
# loss: 0.420011  [   64/60000]
# loss: 0.255825  [ 6464/60000]
# loss: 0.297751  [12864/60000]
# loss: 0.183020  [19264/60000]
# loss: 0.269676  [25664/60000]
# loss: 0.330589  [32064/60000]
# loss: 0.249644  [38464/60000]
# loss: 0.332440  [44864/60000]
# loss: 0.229273  [51264/60000]
# loss: 0.388348  [57664/60000]
# Train Error:
#  Accuracy: 87.7%, Avg loss: 0.005468
#
# Test Error:
#  Accuracy: 85.8%, Avg loss: 0.006266
#
# Epoch 21
# -------------------------------
# loss: 0.405303  [   64/60000]
# loss: 0.249440  [ 6464/60000]
# loss: 0.286960  [12864/60000]
# loss: 0.217821  [19264/60000]
# loss: 0.420610  [25664/60000]
# loss: 0.274019  [32064/60000]
# loss: 0.309575  [38464/60000]
# loss: 0.251107  [44864/60000]
# loss: 0.439421  [51264/60000]
# loss: 0.436147  [57664/60000]
# Train Error:
#  Accuracy: 87.9%, Avg loss: 0.005382
#
# Test Error:
#  Accuracy: 86.4%, Avg loss: 0.006016
#
# Epoch 22
# -------------------------------
# loss: 0.339515  [   64/60000]
# loss: 0.283728  [ 6464/60000]
# loss: 0.340760  [12864/60000]
# loss: 0.346839  [19264/60000]
# loss: 0.502643  [25664/60000]
# loss: 0.291514  [32064/60000]
# loss: 0.228446  [38464/60000]
# loss: 0.395469  [44864/60000]
# loss: 0.309842  [51264/60000]
# loss: 0.305731  [57664/60000]
# Train Error:
#  Accuracy: 88.0%, Avg loss: 0.005312
#
# Test Error:
#  Accuracy: 86.4%, Avg loss: 0.006087
#
# Epoch 23
# -------------------------------
# loss: 0.225738  [   64/60000]
# loss: 0.261759  [ 6464/60000]
# loss: 0.212738  [12864/60000]
# loss: 0.380449  [19264/60000]
# loss: 0.368242  [25664/60000]
# loss: 0.512271  [32064/60000]
# loss: 0.352450  [38464/60000]
# loss: 0.132469  [44864/60000]
# loss: 0.328924  [51264/60000]
# loss: 0.217775  [57664/60000]
# Train Error:
#  Accuracy: 88.2%, Avg loss: 0.005238
#
# Test Error:
#  Accuracy: 85.5%, Avg loss: 0.006187
#
# Epoch 24
# -------------------------------
# loss: 0.271829  [   64/60000]
# loss: 0.501362  [ 6464/60000]
# loss: 0.228665  [12864/60000]
# loss: 0.562634  [19264/60000]
# loss: 0.344526  [25664/60000]
# loss: 0.297587  [32064/60000]
# loss: 0.330138  [38464/60000]
# loss: 0.311860  [44864/60000]
# loss: 0.290680  [51264/60000]
# loss: 0.419585  [57664/60000]
# Train Error:
#  Accuracy: 88.2%, Avg loss: 0.005170
#
# Test Error:
#  Accuracy: 85.7%, Avg loss: 0.006330
#
# Epoch 25
# -------------------------------
# loss: 0.497652  [   64/60000]
# loss: 0.239286  [ 6464/60000]
# loss: 0.325228  [12864/60000]
# loss: 0.224861  [19264/60000]
# loss: 0.275962  [25664/60000]
# loss: 0.378320  [32064/60000]
# loss: 0.344223  [38464/60000]
# loss: 0.357573  [44864/60000]
# loss: 0.318421  [51264/60000]
# loss: 0.219582  [57664/60000]
# Train Error:
#  Accuracy: 88.4%, Avg loss: 0.005113
#
# Test Error:
#  Accuracy: 86.9%, Avg loss: 0.005799
#
# Epoch 26
# -------------------------------
# loss: 0.299129  [   64/60000]
# loss: 0.414574  [ 6464/60000]
# loss: 0.220135  [12864/60000]
# loss: 0.258173  [19264/60000]
# loss: 0.272246  [25664/60000]
# loss: 0.516491  [32064/60000]
# loss: 0.186279  [38464/60000]
# loss: 0.208680  [44864/60000]
# loss: 0.474770  [51264/60000]
# loss: 0.241079  [57664/60000]
# Train Error:
#  Accuracy: 88.5%, Avg loss: 0.005043
#
# Test Error:
#  Accuracy: 86.6%, Avg loss: 0.005874
#
# Epoch 27
# -------------------------------
# loss: 0.267649  [   64/60000]
# loss: 0.340399  [ 6464/60000]
# loss: 0.314679  [12864/60000]
# loss: 0.229428  [19264/60000]
# loss: 0.208881  [25664/60000]
# loss: 0.402595  [32064/60000]
# loss: 0.418228  [38464/60000]
# loss: 0.263325  [44864/60000]
# loss: 0.327630  [51264/60000]
# loss: 0.204033  [57664/60000]
# Train Error:
#  Accuracy: 88.7%, Avg loss: 0.004978
#
# Test Error:
#  Accuracy: 86.4%, Avg loss: 0.005916
#
# Epoch 28
# -------------------------------
# loss: 0.337570  [   64/60000]
# loss: 0.272582  [ 6464/60000]
# loss: 0.418842  [12864/60000]
# loss: 0.302693  [19264/60000]
# loss: 0.180751  [25664/60000]
# loss: 0.374471  [32064/60000]
# loss: 0.227227  [38464/60000]
# loss: 0.248075  [44864/60000]
# loss: 0.310203  [51264/60000]
# loss: 0.251566  [57664/60000]
# Train Error:
#  Accuracy: 88.8%, Avg loss: 0.004913
#
# Test Error:
#  Accuracy: 87.0%, Avg loss: 0.005635
#
# Epoch 29
# -------------------------------
# loss: 0.197958  [   64/60000]
# loss: 0.326263  [ 6464/60000]
# loss: 0.316343  [12864/60000]
# loss: 0.280999  [19264/60000]
# loss: 0.195821  [25664/60000]
# loss: 0.260297  [32064/60000]
# loss: 0.329710  [38464/60000]
# loss: 0.296938  [44864/60000]
# loss: 0.184476  [51264/60000]
# loss: 0.319169  [57664/60000]
# Train Error:
#  Accuracy: 88.9%, Avg loss: 0.004863
#
# Test Error:
#  Accuracy: 87.1%, Avg loss: 0.005656
#
# Epoch 30
# -------------------------------
# loss: 0.231495  [   64/60000]
# loss: 0.191778  [ 6464/60000]
# loss: 0.416711  [12864/60000]
# loss: 0.370338  [19264/60000]
# loss: 0.218901  [25664/60000]
# loss: 0.253293  [32064/60000]
# loss: 0.227529  [38464/60000]
# loss: 0.254081  [44864/60000]
# loss: 0.305046  [51264/60000]
# loss: 0.304287  [57664/60000]
# Train Error:
#  Accuracy: 89.1%, Avg loss: 0.004789
#
# Test Error:
#  Accuracy: 87.0%, Avg loss: 0.005692
#
# Epoch 31
# -------------------------------
# loss: 0.418787  [   64/60000]
# loss: 0.295784  [ 6464/60000]
# loss: 0.525504  [12864/60000]
# loss: 0.300211  [19264/60000]
# loss: 0.394942  [25664/60000]
# loss: 0.228983  [32064/60000]
# loss: 0.324668  [38464/60000]
# loss: 0.495188  [44864/60000]
# loss: 0.355604  [51264/60000]
# loss: 0.552377  [57664/60000]
# Train Error:
#  Accuracy: 89.3%, Avg loss: 0.004731
#
# Test Error:
#  Accuracy: 86.1%, Avg loss: 0.006005
#
# Epoch 32
# -------------------------------
# loss: 0.245366  [   64/60000]
# loss: 0.188812  [ 6464/60000]
# loss: 0.187991  [12864/60000]
# loss: 0.329563  [19264/60000]
# loss: 0.177900  [25664/60000]
# loss: 0.381541  [32064/60000]
# loss: 0.252628  [38464/60000]
# loss: 0.284798  [44864/60000]
# loss: 0.190198  [51264/60000]
# loss: 0.352703  [57664/60000]
# Train Error:
#  Accuracy: 89.3%, Avg loss: 0.004692
#
# Test Error:
#  Accuracy: 87.5%, Avg loss: 0.005520
#
# Epoch 33
# -------------------------------
# loss: 0.270202  [   64/60000]
# loss: 0.295827  [ 6464/60000]
# loss: 0.270740  [12864/60000]
# loss: 0.366069  [19264/60000]
# loss: 0.341333  [25664/60000]
# loss: 0.272050  [32064/60000]
# loss: 0.218953  [38464/60000]
# loss: 0.318225  [44864/60000]
# loss: 0.277004  [51264/60000]
# loss: 0.261682  [57664/60000]
# Train Error:
#  Accuracy: 89.4%, Avg loss: 0.004626
#
# Test Error:
#  Accuracy: 87.1%, Avg loss: 0.005637
#
# Epoch 34
# -------------------------------
# loss: 0.269018  [   64/60000]
# loss: 0.259842  [ 6464/60000]
# loss: 0.219761  [12864/60000]
# loss: 0.276874  [19264/60000]
# loss: 0.281301  [25664/60000]
# loss: 0.276116  [32064/60000]
# loss: 0.222897  [38464/60000]
# loss: 0.257697  [44864/60000]
# loss: 0.254113  [51264/60000]
# loss: 0.149078  [57664/60000]
# Train Error:
#  Accuracy: 89.5%, Avg loss: 0.004581
#
# Test Error:
#  Accuracy: 87.0%, Avg loss: 0.005683
#
# Epoch 35
# -------------------------------
# loss: 0.326084  [   64/60000]
# loss: 0.270202  [ 6464/60000]
# loss: 0.342596  [12864/60000]
# loss: 0.183343  [19264/60000]
# loss: 0.324053  [25664/60000]
# loss: 0.428974  [32064/60000]
# loss: 0.161974  [38464/60000]
# loss: 0.216029  [44864/60000]
# loss: 0.300675  [51264/60000]
# loss: 0.361546  [57664/60000]
# Train Error:
#  Accuracy: 89.7%, Avg loss: 0.004527
#
# Test Error:
#  Accuracy: 87.1%, Avg loss: 0.005616
#
# Epoch 36
# -------------------------------
# loss: 0.352135  [   64/60000]
# loss: 0.352589  [ 6464/60000]
# loss: 0.325717  [12864/60000]
# loss: 0.301610  [19264/60000]
# loss: 0.242914  [25664/60000]
# loss: 0.248138  [32064/60000]
# loss: 0.211458  [38464/60000]
# loss: 0.331597  [44864/60000]
# loss: 0.426227  [51264/60000]
# loss: 0.230446  [57664/60000]
# Train Error:
#  Accuracy: 89.9%, Avg loss: 0.004474
#
# Test Error:
#  Accuracy: 87.3%, Avg loss: 0.005520
#
# Epoch 37
# -------------------------------
# loss: 0.169226  [   64/60000]
# loss: 0.184067  [ 6464/60000]
# loss: 0.346474  [12864/60000]
# loss: 0.308799  [19264/60000]
# loss: 0.321330  [25664/60000]
# loss: 0.252910  [32064/60000]
# loss: 0.227655  [38464/60000]
# loss: 0.289943  [44864/60000]
# loss: 0.307714  [51264/60000]
# loss: 0.249924  [57664/60000]
# Train Error:
#  Accuracy: 89.9%, Avg loss: 0.004420
#
# Test Error:
#  Accuracy: 87.3%, Avg loss: 0.005552
#
# Epoch 38
# -------------------------------
# loss: 0.409705  [   64/60000]
# loss: 0.171839  [ 6464/60000]
# loss: 0.400741  [12864/60000]
# loss: 0.471024  [19264/60000]
# loss: 0.260006  [25664/60000]
# loss: 0.409269  [32064/60000]
# loss: 0.208142  [38464/60000]
# loss: 0.227878  [44864/60000]
# loss: 0.498896  [51264/60000]
# loss: 0.247757  [57664/60000]
# Train Error:
#  Accuracy: 90.0%, Avg loss: 0.004377
#
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.005387
#
# Epoch 39
# -------------------------------
# loss: 0.291714  [   64/60000]
# loss: 0.237228  [ 6464/60000]
# loss: 0.387605  [12864/60000]
# loss: 0.320350  [19264/60000]
# loss: 0.324793  [25664/60000]
# loss: 0.246950  [32064/60000]
# loss: 0.179073  [38464/60000]
# loss: 0.109634  [44864/60000]
# loss: 0.343767  [51264/60000]
# loss: 0.235836  [57664/60000]
# Train Error:
#  Accuracy: 90.0%, Avg loss: 0.004342
#
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.005405
#
# Epoch 40
# -------------------------------
# loss: 0.130739  [   64/60000]
# loss: 0.320513  [ 6464/60000]
# loss: 0.255936  [12864/60000]
# loss: 0.370727  [19264/60000]
# loss: 0.194962  [25664/60000]
# loss: 0.375763  [32064/60000]
# loss: 0.443734  [38464/60000]
# loss: 0.264730  [44864/60000]
# loss: 0.335528  [51264/60000]
# loss: 0.274047  [57664/60000]
# Train Error:
#  Accuracy: 90.3%, Avg loss: 0.004289
#
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.005378
#
# Epoch 41
# -------------------------------
# loss: 0.356387  [   64/60000]
# loss: 0.163806  [ 6464/60000]
# loss: 0.240487  [12864/60000]
# loss: 0.327534  [19264/60000]
# loss: 0.211026  [25664/60000]
# loss: 0.302300  [32064/60000]
# loss: 0.262568  [38464/60000]
# loss: 0.255837  [44864/60000]
# loss: 0.248902  [51264/60000]
# loss: 0.183130  [57664/60000]
# Train Error:
#  Accuracy: 90.2%, Avg loss: 0.004255
#
# Test Error:
#  Accuracy: 86.5%, Avg loss: 0.005871
#
# Epoch 42
# -------------------------------
# loss: 0.209276  [   64/60000]
# loss: 0.296147  [ 6464/60000]
# loss: 0.077455  [12864/60000]
# loss: 0.292311  [19264/60000]
# loss: 0.313556  [25664/60000]
# loss: 0.359324  [32064/60000]
# loss: 0.253791  [38464/60000]
# loss: 0.227989  [44864/60000]
# loss: 0.307314  [51264/60000]
# loss: 0.116499  [57664/60000]
# Train Error:
#  Accuracy: 90.4%, Avg loss: 0.004213
#
# Test Error:
#  Accuracy: 87.9%, Avg loss: 0.005317
#
# Epoch 43
# -------------------------------
# loss: 0.373574  [   64/60000]
# loss: 0.251641  [ 6464/60000]
# loss: 0.269272  [12864/60000]
# loss: 0.256108  [19264/60000]
# loss: 0.231726  [25664/60000]
# loss: 0.154141  [32064/60000]
# loss: 0.286021  [38464/60000]
# loss: 0.391348  [44864/60000]
# loss: 0.260820  [51264/60000]
# loss: 0.317594  [57664/60000]
# Train Error:
#  Accuracy: 90.5%, Avg loss: 0.004152
#
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.005390
#
# Epoch 44
# -------------------------------
# loss: 0.305545  [   64/60000]
# loss: 0.301462  [ 6464/60000]
# loss: 0.183157  [12864/60000]
# loss: 0.285166  [19264/60000]
# loss: 0.171748  [25664/60000]
# loss: 0.371213  [32064/60000]
# loss: 0.277412  [38464/60000]
# loss: 0.442071  [44864/60000]
# loss: 0.205226  [51264/60000]
# loss: 0.396346  [57664/60000]
# Train Error:
#  Accuracy: 90.6%, Avg loss: 0.004114
#
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.005288
#
# Epoch 45
# -------------------------------
# loss: 0.134025  [   64/60000]
# loss: 0.390348  [ 6464/60000]
# loss: 0.199387  [12864/60000]
# loss: 0.189693  [19264/60000]
# loss: 0.344946  [25664/60000]
# loss: 0.139074  [32064/60000]
# loss: 0.475914  [38464/60000]
# loss: 0.383155  [44864/60000]
# loss: 0.339506  [51264/60000]
# loss: 0.232765  [57664/60000]
# Train Error:
#  Accuracy: 90.7%, Avg loss: 0.004072
#
# Test Error:
#  Accuracy: 87.4%, Avg loss: 0.005431
#
# Epoch 46
# -------------------------------
# loss: 0.181452  [   64/60000]
# loss: 0.262199  [ 6464/60000]
# loss: 0.145527  [12864/60000]
# loss: 0.189670  [19264/60000]
# loss: 0.183000  [25664/60000]
# loss: 0.262188  [32064/60000]
# loss: 0.108647  [38464/60000]
# loss: 0.310990  [44864/60000]
# loss: 0.179538  [51264/60000]
# loss: 0.202057  [57664/60000]
# Train Error:
#  Accuracy: 90.8%, Avg loss: 0.004025
#
# Test Error:
#  Accuracy: 86.1%, Avg loss: 0.005936
#
# Epoch 47
# -------------------------------
# loss: 0.284610  [   64/60000]
# loss: 0.116521  [ 6464/60000]
# loss: 0.111661  [12864/60000]
# loss: 0.209950  [19264/60000]
# loss: 0.263895  [25664/60000]
# loss: 0.241537  [32064/60000]
# loss: 0.168843  [38464/60000]
# loss: 0.146045  [44864/60000]
# loss: 0.177194  [51264/60000]
# loss: 0.114660  [57664/60000]
# Train Error:
#  Accuracy: 91.0%, Avg loss: 0.003981
#
# Test Error:
#  Accuracy: 88.0%, Avg loss: 0.005226
#
# Epoch 48
# -------------------------------
# loss: 0.185231  [   64/60000]
# loss: 0.304108  [ 6464/60000]
# loss: 0.260014  [12864/60000]
# loss: 0.180093  [19264/60000]
# loss: 0.291975  [25664/60000]
# loss: 0.241381  [32064/60000]
# loss: 0.304550  [38464/60000]
# loss: 0.229864  [44864/60000]
# loss: 0.292797  [51264/60000]
# loss: 0.120490  [57664/60000]
# Train Error:
#  Accuracy: 90.9%, Avg loss: 0.003959
#
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.005352
#
# Epoch 49
# -------------------------------
# loss: 0.350253  [   64/60000]
# loss: 0.458897  [ 6464/60000]
# loss: 0.221056  [12864/60000]
# loss: 0.268554  [19264/60000]
# loss: 0.307070  [25664/60000]
# loss: 0.211115  [32064/60000]
# loss: 0.199162  [38464/60000]
# loss: 0.350748  [44864/60000]
# loss: 0.230769  [51264/60000]
# loss: 0.237016  [57664/60000]
# Train Error:
#  Accuracy: 91.1%, Avg loss: 0.003919
#
# Test Error:
#  Accuracy: 88.4%, Avg loss: 0.005120
#
# Epoch 50
# -------------------------------
# loss: 0.125026  [   64/60000]
# loss: 0.296375  [ 6464/60000]
# loss: 0.149972  [12864/60000]
# loss: 0.251671  [19264/60000]
# loss: 0.237043  [25664/60000]
# loss: 0.161706  [32064/60000]
# loss: 0.272518  [38464/60000]
# loss: 0.375987  [44864/60000]
# loss: 0.309679  [51264/60000]
# loss: 0.203047  [57664/60000]
# Train Error:
#  Accuracy: 91.2%, Avg loss: 0.003863
#
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.005233
#
# Epoch 51
# -------------------------------
# loss: 0.406105  [   64/60000]
# loss: 0.193395  [ 6464/60000]
# loss: 0.213107  [12864/60000]
# loss: 0.337665  [19264/60000]
# loss: 0.208930  [25664/60000]
# loss: 0.243006  [32064/60000]
# loss: 0.259944  [38464/60000]
# loss: 0.205415  [44864/60000]
# loss: 0.206044  [51264/60000]
# loss: 0.184775  [57664/60000]
# Train Error:
#  Accuracy: 91.3%, Avg loss: 0.003822
#
# Test Error:
#  Accuracy: 88.3%, Avg loss: 0.005181
#
# Epoch 52
# -------------------------------
# loss: 0.362335  [   64/60000]
# loss: 0.175526  [ 6464/60000]
# loss: 0.283962  [12864/60000]
# loss: 0.206142  [19264/60000]
# loss: 0.253278  [25664/60000]
# loss: 0.259978  [32064/60000]
# loss: 0.350427  [38464/60000]
# loss: 0.333028  [44864/60000]
# loss: 0.196156  [51264/60000]
# loss: 0.259415  [57664/60000]
# Train Error:
#  Accuracy: 91.4%, Avg loss: 0.003784
#
# Test Error:
#  Accuracy: 87.0%, Avg loss: 0.005669
#
# Epoch 53
# -------------------------------
# loss: 0.451671  [   64/60000]
# loss: 0.156436  [ 6464/60000]
# loss: 0.193528  [12864/60000]
# loss: 0.428792  [19264/60000]
# loss: 0.338429  [25664/60000]
# loss: 0.206005  [32064/60000]
# loss: 0.134620  [38464/60000]
# loss: 0.289116  [44864/60000]
# loss: 0.252410  [51264/60000]
# loss: 0.159141  [57664/60000]
# Train Error:
#  Accuracy: 91.5%, Avg loss: 0.003756
#
# Test Error:
#  Accuracy: 86.4%, Avg loss: 0.005979
#
# Epoch 54
# -------------------------------
# loss: 0.149224  [   64/60000]
# loss: 0.410587  [ 6464/60000]
# loss: 0.319763  [12864/60000]
# loss: 0.210670  [19264/60000]
# loss: 0.439755  [25664/60000]
# loss: 0.267895  [32064/60000]
# loss: 0.206271  [38464/60000]
# loss: 0.275065  [44864/60000]
# loss: 0.294317  [51264/60000]
# loss: 0.176050  [57664/60000]
# Train Error:
#  Accuracy: 91.6%, Avg loss: 0.003718
#
# Test Error:
#  Accuracy: 88.5%, Avg loss: 0.005131
#
# Epoch 55
# -------------------------------
# loss: 0.299960  [   64/60000]
# loss: 0.302535  [ 6464/60000]
# loss: 0.282662  [12864/60000]
# loss: 0.234179  [19264/60000]
# loss: 0.073242  [25664/60000]
# loss: 0.220713  [32064/60000]
# loss: 0.193570  [38464/60000]
# loss: 0.162709  [44864/60000]
# loss: 0.128530  [51264/60000]
# loss: 0.271094  [57664/60000]
# Train Error:
#  Accuracy: 91.6%, Avg loss: 0.003688
#
# Test Error:
#  Accuracy: 88.5%, Avg loss: 0.005113
#
# Epoch 56
# -------------------------------
# loss: 0.286984  [   64/60000]
# loss: 0.478144  [ 6464/60000]
# loss: 0.158322  [12864/60000]
# loss: 0.240417  [19264/60000]
# loss: 0.570897  [25664/60000]
# loss: 0.140883  [32064/60000]
# loss: 0.175891  [38464/60000]
# loss: 0.270185  [44864/60000]
# loss: 0.145911  [51264/60000]
# loss: 0.395881  [57664/60000]
# Train Error:
#  Accuracy: 91.6%, Avg loss: 0.003641
#
# Test Error:
#  Accuracy: 88.7%, Avg loss: 0.005018
#
# Epoch 57
# -------------------------------
# loss: 0.227473  [   64/60000]
# loss: 0.304349  [ 6464/60000]
# loss: 0.275505  [12864/60000]
# loss: 0.221740  [19264/60000]
# loss: 0.170435  [25664/60000]
# loss: 0.254818  [32064/60000]
# loss: 0.154672  [38464/60000]
# loss: 0.159968  [44864/60000]
# loss: 0.187045  [51264/60000]
# loss: 0.109246  [57664/60000]
# Train Error:
#  Accuracy: 91.8%, Avg loss: 0.003586
#
# Test Error:
#  Accuracy: 88.8%, Avg loss: 0.005020
#
# Epoch 58
# -------------------------------
# loss: 0.250923  [   64/60000]
# loss: 0.250665  [ 6464/60000]
# loss: 0.199176  [12864/60000]
# loss: 0.420618  [19264/60000]
# loss: 0.150693  [25664/60000]
# loss: 0.209005  [32064/60000]
# loss: 0.221957  [38464/60000]
# loss: 0.259522  [44864/60000]
# loss: 0.273009  [51264/60000]
# loss: 0.265780  [57664/60000]
# Train Error:
#  Accuracy: 91.8%, Avg loss: 0.003589
#
# Test Error:
#  Accuracy: 88.4%, Avg loss: 0.005212
#
# Epoch 59
# -------------------------------
# loss: 0.094699  [   64/60000]
# loss: 0.105836  [ 6464/60000]
# loss: 0.259503  [12864/60000]
# loss: 0.129041  [19264/60000]
# loss: 0.193944  [25664/60000]
# loss: 0.177682  [32064/60000]
# loss: 0.285194  [38464/60000]
# loss: 0.314094  [44864/60000]
# loss: 0.305234  [51264/60000]
# loss: 0.202675  [57664/60000]
# Train Error:
#  Accuracy: 91.9%, Avg loss: 0.003528
#
# Test Error:
#  Accuracy: 87.5%, Avg loss: 0.005539
#
# Epoch 60
# -------------------------------
# loss: 0.243814  [   64/60000]
# loss: 0.183585  [ 6464/60000]
# loss: 0.202847  [12864/60000]
# loss: 0.323724  [19264/60000]
# loss: 0.126870  [25664/60000]
# loss: 0.283797  [32064/60000]
# loss: 0.134704  [38464/60000]
# loss: 0.255239  [44864/60000]
# loss: 0.247656  [51264/60000]
# loss: 0.307028  [57664/60000]
# Train Error:
#  Accuracy: 92.0%, Avg loss: 0.003490
#
# Test Error:
#  Accuracy: 88.8%, Avg loss: 0.005040
#
# Epoch 61
# -------------------------------
# loss: 0.174437  [   64/60000]
# loss: 0.192269  [ 6464/60000]
# loss: 0.188673  [12864/60000]
# loss: 0.252942  [19264/60000]
# loss: 0.191945  [25664/60000]
# loss: 0.364320  [32064/60000]
# loss: 0.264596  [38464/60000]
# loss: 0.267874  [44864/60000]
# loss: 0.146678  [51264/60000]
# loss: 0.127904  [57664/60000]
# Train Error:
#  Accuracy: 92.2%, Avg loss: 0.003463
#
# Test Error:
#  Accuracy: 88.7%, Avg loss: 0.005022
#
# Epoch 62
# -------------------------------
# loss: 0.152145  [   64/60000]
# loss: 0.192424  [ 6464/60000]
# loss: 0.191215  [12864/60000]
# loss: 0.146097  [19264/60000]
# loss: 0.332908  [25664/60000]
# loss: 0.221470  [32064/60000]
# loss: 0.119348  [38464/60000]
# loss: 0.215254  [44864/60000]
# loss: 0.172402  [51264/60000]
# loss: 0.121243  [57664/60000]
# Train Error:
#  Accuracy: 92.3%, Avg loss: 0.003430
#
# Test Error:
#  Accuracy: 88.7%, Avg loss: 0.005027
#
# Epoch 63
# -------------------------------
# loss: 0.262719  [   64/60000]
# loss: 0.155447  [ 6464/60000]
# loss: 0.135979  [12864/60000]
# loss: 0.269179  [19264/60000]
# loss: 0.194098  [25664/60000]
# loss: 0.252813  [32064/60000]
# loss: 0.402320  [38464/60000]
# loss: 0.230806  [44864/60000]
# loss: 0.161834  [51264/60000]
# loss: 0.145629  [57664/60000]
# Train Error:
#  Accuracy: 92.3%, Avg loss: 0.003386
#
# Test Error:
#  Accuracy: 88.7%, Avg loss: 0.005078
#
# Epoch 64
# -------------------------------
# loss: 0.303160  [   64/60000]
# loss: 0.212874  [ 6464/60000]
# loss: 0.228138  [12864/60000]
# loss: 0.164825  [19264/60000]
# loss: 0.103740  [25664/60000]
# loss: 0.242515  [32064/60000]
# loss: 0.161495  [38464/60000]
# loss: 0.234305  [44864/60000]
# loss: 0.137758  [51264/60000]
# loss: 0.335693  [57664/60000]
# Train Error:
#  Accuracy: 92.3%, Avg loss: 0.003367
#
# Test Error:
#  Accuracy: 87.3%, Avg loss: 0.005513
#
# Epoch 65
# -------------------------------
# loss: 0.222699  [   64/60000]
# loss: 0.175389  [ 6464/60000]
# loss: 0.207608  [12864/60000]
# loss: 0.209144  [19264/60000]
# loss: 0.313888  [25664/60000]
# loss: 0.318103  [32064/60000]
# loss: 0.287644  [38464/60000]
# loss: 0.155280  [44864/60000]
# loss: 0.135270  [51264/60000]
# loss: 0.322581  [57664/60000]
# Train Error:
#  Accuracy: 92.5%, Avg loss: 0.003325
#
# Test Error:
#  Accuracy: 87.3%, Avg loss: 0.005585
#
# Epoch 66
# -------------------------------
# loss: 0.386255  [   64/60000]
# loss: 0.220054  [ 6464/60000]
# loss: 0.178881  [12864/60000]
# loss: 0.228704  [19264/60000]
# loss: 0.177527  [25664/60000]
# loss: 0.253852  [32064/60000]
# loss: 0.076686  [38464/60000]
# loss: 0.325216  [44864/60000]
# loss: 0.286546  [51264/60000]
# loss: 0.272263  [57664/60000]
# Train Error:
#  Accuracy: 92.5%, Avg loss: 0.003277
#
# Test Error:
#  Accuracy: 87.9%, Avg loss: 0.005400
#
# Epoch 67
# -------------------------------
# loss: 0.261743  [   64/60000]
# loss: 0.313811  [ 6464/60000]
# loss: 0.273454  [12864/60000]
# loss: 0.202952  [19264/60000]
# loss: 0.372219  [25664/60000]
# loss: 0.307241  [32064/60000]
# loss: 0.233034  [38464/60000]
# loss: 0.231064  [44864/60000]
# loss: 0.164177  [51264/60000]
# loss: 0.185661  [57664/60000]
# Train Error:
#  Accuracy: 92.6%, Avg loss: 0.003255
#
# Test Error:
#  Accuracy: 87.6%, Avg loss: 0.005530
#
# Epoch 68
# -------------------------------
# loss: 0.217182  [   64/60000]
# loss: 0.083806  [ 6464/60000]
# loss: 0.202686  [12864/60000]
# loss: 0.120973  [19264/60000]
# loss: 0.179674  [25664/60000]
# loss: 0.235893  [32064/60000]
# loss: 0.318437  [38464/60000]
# loss: 0.340502  [44864/60000]
# loss: 0.157070  [51264/60000]
# loss: 0.269719  [57664/60000]
# Train Error:
#  Accuracy: 92.7%, Avg loss: 0.003216
#
# Test Error:
#  Accuracy: 88.8%, Avg loss: 0.005012
#
# Epoch 69
# -------------------------------
# loss: 0.207736  [   64/60000]
# loss: 0.158318  [ 6464/60000]
# loss: 0.236318  [12864/60000]
# loss: 0.113785  [19264/60000]
# loss: 0.125365  [25664/60000]
# loss: 0.213455  [32064/60000]
# loss: 0.284147  [38464/60000]
# loss: 0.248920  [44864/60000]
# loss: 0.219202  [51264/60000]
# loss: 0.178481  [57664/60000]
# Train Error:
#  Accuracy: 92.8%, Avg loss: 0.003196
#
# Test Error:
#  Accuracy: 88.7%, Avg loss: 0.004997
#
# Epoch 70
# -------------------------------
# loss: 0.156544  [   64/60000]
# loss: 0.168194  [ 6464/60000]
# loss: 0.181465  [12864/60000]
# loss: 0.253468  [19264/60000]
# loss: 0.127020  [25664/60000]
# loss: 0.273335  [32064/60000]
# loss: 0.199508  [38464/60000]
# loss: 0.137839  [44864/60000]
# loss: 0.273552  [51264/60000]
# loss: 0.239342  [57664/60000]
# Train Error:
#  Accuracy: 92.8%, Avg loss: 0.003168
#
# Test Error:
#  Accuracy: 88.9%, Avg loss: 0.004969
#
# Epoch 71
# -------------------------------
# loss: 0.247578  [   64/60000]
# loss: 0.137036  [ 6464/60000]
# loss: 0.190143  [12864/60000]
# loss: 0.199754  [19264/60000]
# loss: 0.197903  [25664/60000]
# loss: 0.439251  [32064/60000]
# loss: 0.284474  [38464/60000]
# loss: 0.169815  [44864/60000]
# loss: 0.221181  [51264/60000]
# loss: 0.145844  [57664/60000]
# Train Error:
#  Accuracy: 92.9%, Avg loss: 0.003128
#
# Test Error:
#  Accuracy: 89.0%, Avg loss: 0.005024
#
# Epoch 72
# -------------------------------
# loss: 0.133427  [   64/60000]
# loss: 0.097412  [ 6464/60000]
# loss: 0.095319  [12864/60000]
# loss: 0.163538  [19264/60000]
# loss: 0.238365  [25664/60000]
# loss: 0.143892  [32064/60000]
# loss: 0.167328  [38464/60000]
# loss: 0.151134  [44864/60000]
# loss: 0.148389  [51264/60000]
# loss: 0.215018  [57664/60000]
# Train Error:
#  Accuracy: 93.1%, Avg loss: 0.003097
#
# Test Error:
#  Accuracy: 89.1%, Avg loss: 0.005046
#
# Epoch 73
# -------------------------------
# loss: 0.125558  [   64/60000]
# loss: 0.170306  [ 6464/60000]
# loss: 0.249522  [12864/60000]
# loss: 0.139572  [19264/60000]
# loss: 0.258956  [25664/60000]
# loss: 0.248215  [32064/60000]
# loss: 0.238372  [38464/60000]
# loss: 0.291978  [44864/60000]
# loss: 0.190349  [51264/60000]
# loss: 0.118026  [57664/60000]
# Train Error:
#  Accuracy: 93.0%, Avg loss: 0.003075
#
# Test Error:
#  Accuracy: 86.4%, Avg loss: 0.005982
#
# Epoch 74
# -------------------------------
# loss: 0.231105  [   64/60000]
# loss: 0.130008  [ 6464/60000]
# loss: 0.132689  [12864/60000]
# loss: 0.175946  [19264/60000]
# loss: 0.217049  [25664/60000]
# loss: 0.139499  [32064/60000]
# loss: 0.257348  [38464/60000]
# loss: 0.294951  [44864/60000]
# loss: 0.307497  [51264/60000]
# loss: 0.217377  [57664/60000]
# Train Error:
#  Accuracy: 93.2%, Avg loss: 0.003041
#
# Test Error:
#  Accuracy: 88.1%, Avg loss: 0.005317
#
# Epoch 75
# -------------------------------
# loss: 0.225809  [   64/60000]
# loss: 0.146245  [ 6464/60000]
# loss: 0.186459  [12864/60000]
# loss: 0.134514  [19264/60000]
# loss: 0.232228  [25664/60000]
# loss: 0.139488  [32064/60000]
# loss: 0.284257  [38464/60000]
# loss: 0.206188  [44864/60000]
# loss: 0.251713  [51264/60000]
# loss: 0.329321  [57664/60000]
# Train Error:
#  Accuracy: 93.2%, Avg loss: 0.002999
#
# Test Error:
#  Accuracy: 88.7%, Avg loss: 0.005067
#
# Epoch 76
# -------------------------------
# loss: 0.047044  [   64/60000]
# loss: 0.155856  [ 6464/60000]
# loss: 0.187891  [12864/60000]
# loss: 0.252062  [19264/60000]
# loss: 0.218170  [25664/60000]
# loss: 0.248762  [32064/60000]
# loss: 0.180042  [38464/60000]
# loss: 0.131305  [44864/60000]
# loss: 0.118421  [51264/60000]
# loss: 0.186145  [57664/60000]
# Train Error:
#  Accuracy: 93.3%, Avg loss: 0.002971
#
# Test Error:
#  Accuracy: 88.2%, Avg loss: 0.005319
#
# Epoch 77
# -------------------------------
# loss: 0.204260  [   64/60000]
# loss: 0.220544  [ 6464/60000]
# loss: 0.314789  [12864/60000]
# loss: 0.106353  [19264/60000]
# loss: 0.285879  [25664/60000]
# loss: 0.234675  [32064/60000]
# loss: 0.150422  [38464/60000]
# loss: 0.279923  [44864/60000]
# loss: 0.145495  [51264/60000]
# loss: 0.307605  [57664/60000]
# Train Error:
#  Accuracy: 93.3%, Avg loss: 0.002956
#
# Test Error:
#  Accuracy: 89.0%, Avg loss: 0.004889
#
# Epoch 78
# -------------------------------
# loss: 0.072619  [   64/60000]
# loss: 0.256468  [ 6464/60000]
# loss: 0.185228  [12864/60000]
# loss: 0.167003  [19264/60000]
# loss: 0.166777  [25664/60000]
# loss: 0.120487  [32064/60000]
# loss: 0.238338  [38464/60000]
# loss: 0.102591  [44864/60000]
# loss: 0.129227  [51264/60000]
# loss: 0.192111  [57664/60000]
# Train Error:
#  Accuracy: 93.4%, Avg loss: 0.002905
#
# Test Error:
#  Accuracy: 88.3%, Avg loss: 0.005323
#
# Epoch 79
# -------------------------------
# loss: 0.128455  [   64/60000]
# loss: 0.118754  [ 6464/60000]
# loss: 0.141146  [12864/60000]
# loss: 0.295928  [19264/60000]
# loss: 0.271017  [25664/60000]
# loss: 0.120521  [32064/60000]
# loss: 0.285147  [38464/60000]
# loss: 0.117397  [44864/60000]
# loss: 0.137850  [51264/60000]
# loss: 0.123191  [57664/60000]
# Train Error:
#  Accuracy: 93.4%, Avg loss: 0.002905
#
# Test Error:
#  Accuracy: 89.1%, Avg loss: 0.004976
#
# Epoch 80
# -------------------------------
# loss: 0.247728  [   64/60000]
# loss: 0.162827  [ 6464/60000]
# loss: 0.179944  [12864/60000]
# loss: 0.281136  [19264/60000]
# loss: 0.204416  [25664/60000]
# loss: 0.198661  [32064/60000]
# loss: 0.097674  [38464/60000]
# loss: 0.296443  [44864/60000]
# loss: 0.210003  [51264/60000]
# loss: 0.128042  [57664/60000]
# Train Error:
#  Accuracy: 93.5%, Avg loss: 0.002867
#
# Test Error:
#  Accuracy: 88.7%, Avg loss: 0.005041
#
# Epoch 81
# -------------------------------
# loss: 0.088225  [   64/60000]
# loss: 0.206059  [ 6464/60000]
# loss: 0.225825  [12864/60000]
# loss: 0.199709  [19264/60000]
# loss: 0.127675  [25664/60000]
# loss: 0.203286  [32064/60000]
# loss: 0.281298  [38464/60000]
# loss: 0.132517  [44864/60000]
# loss: 0.211597  [51264/60000]
# loss: 0.215559  [57664/60000]
# Train Error:
#  Accuracy: 93.7%, Avg loss: 0.002826
#
# Test Error:
#  Accuracy: 88.8%, Avg loss: 0.005049
#
# Epoch 82
# -------------------------------
# loss: 0.225764  [   64/60000]
# loss: 0.177528  [ 6464/60000]
# loss: 0.129184  [12864/60000]
# loss: 0.135268  [19264/60000]
# loss: 0.179501  [25664/60000]
# loss: 0.120247  [32064/60000]
# loss: 0.222578  [38464/60000]
# loss: 0.114268  [44864/60000]
# loss: 0.397209  [51264/60000]
# loss: 0.149947  [57664/60000]
# Train Error:
#  Accuracy: 93.7%, Avg loss: 0.002804
#
# Test Error:
#  Accuracy: 88.5%, Avg loss: 0.005283
#
# Epoch 83
# -------------------------------
# loss: 0.171759  [   64/60000]
# loss: 0.131446  [ 6464/60000]
# loss: 0.151864  [12864/60000]
# loss: 0.133759  [19264/60000]
# loss: 0.137925  [25664/60000]
# loss: 0.120360  [32064/60000]
# loss: 0.135684  [38464/60000]
# loss: 0.188867  [44864/60000]
# loss: 0.146304  [51264/60000]
# loss: 0.168042  [57664/60000]
# Train Error:
#  Accuracy: 93.8%, Avg loss: 0.002781
#
# Test Error:
#  Accuracy: 89.0%, Avg loss: 0.004934
#
# Epoch 84
# -------------------------------
# loss: 0.139234  [   64/60000]
# loss: 0.169243  [ 6464/60000]
# loss: 0.299351  [12864/60000]
# loss: 0.269719  [19264/60000]
# loss: 0.083811  [25664/60000]
# loss: 0.173296  [32064/60000]
# loss: 0.078429  [38464/60000]
# loss: 0.175882  [44864/60000]
# loss: 0.171618  [51264/60000]
# loss: 0.063818  [57664/60000]
# Train Error:
#  Accuracy: 93.9%, Avg loss: 0.002743
#
# Test Error:
#  Accuracy: 88.9%, Avg loss: 0.005052
#
# Epoch 85
# -------------------------------
# loss: 0.152964  [   64/60000]
# loss: 0.200054  [ 6464/60000]
# loss: 0.177474  [12864/60000]
# loss: 0.154867  [19264/60000]
# loss: 0.116828  [25664/60000]
# loss: 0.140974  [32064/60000]
# loss: 0.274171  [38464/60000]
# loss: 0.104299  [44864/60000]
# loss: 0.122598  [51264/60000]
# loss: 0.142697  [57664/60000]
# Train Error:
#  Accuracy: 93.9%, Avg loss: 0.002712
#
# Test Error:
#  Accuracy: 87.8%, Avg loss: 0.005501
#
# Epoch 86
# -------------------------------
# loss: 0.316295  [   64/60000]
# loss: 0.155367  [ 6464/60000]
# loss: 0.153595  [12864/60000]
# loss: 0.138494  [19264/60000]
# loss: 0.072827  [25664/60000]
# loss: 0.122833  [32064/60000]
# loss: 0.287695  [38464/60000]
# loss: 0.127114  [44864/60000]
# loss: 0.129114  [51264/60000]
# loss: 0.085771  [57664/60000]
# Train Error:
#  Accuracy: 94.0%, Avg loss: 0.002676
#
# Test Error:
#  Accuracy: 87.7%, Avg loss: 0.005774
#
# Epoch 87
# -------------------------------
# loss: 0.304864  [   64/60000]
# loss: 0.145926  [ 6464/60000]
# loss: 0.161154  [12864/60000]
# loss: 0.099958  [19264/60000]
# loss: 0.272772  [25664/60000]
# loss: 0.176489  [32064/60000]
# loss: 0.168684  [38464/60000]
# loss: 0.127862  [44864/60000]
# loss: 0.080369  [51264/60000]
# loss: 0.234259  [57664/60000]
# Train Error:
#  Accuracy: 94.0%, Avg loss: 0.002662
#
# Test Error:
#  Accuracy: 89.4%, Avg loss: 0.004915
#
# Epoch 88
# -------------------------------
# loss: 0.153022  [   64/60000]
# loss: 0.113781  [ 6464/60000]
# loss: 0.257782  [12864/60000]
# loss: 0.198382  [19264/60000]
# loss: 0.208012  [25664/60000]
# loss: 0.225758  [32064/60000]
# loss: 0.075530  [38464/60000]
# loss: 0.209936  [44864/60000]
# loss: 0.153380  [51264/60000]
# loss: 0.129672  [57664/60000]
# Train Error:
#  Accuracy: 94.0%, Avg loss: 0.002638
#
# Test Error:
#  Accuracy: 87.5%, Avg loss: 0.005596
#
# Epoch 89
# -------------------------------
# loss: 0.307059  [   64/60000]
# loss: 0.175624  [ 6464/60000]
# loss: 0.143927  [12864/60000]
# loss: 0.131892  [19264/60000]
# loss: 0.127340  [25664/60000]
# loss: 0.204519  [32064/60000]
# loss: 0.157210  [38464/60000]
# loss: 0.368640  [44864/60000]
# loss: 0.165108  [51264/60000]
# loss: 0.153068  [57664/60000]
# Train Error:
#  Accuracy: 94.2%, Avg loss: 0.002612
#
# Test Error:
#  Accuracy: 89.0%, Avg loss: 0.005093
#
# Epoch 90
# -------------------------------
# loss: 0.283039  [   64/60000]
# loss: 0.129942  [ 6464/60000]
# loss: 0.104786  [12864/60000]
# loss: 0.215966  [19264/60000]
# loss: 0.139930  [25664/60000]
# loss: 0.152864  [32064/60000]
# loss: 0.097015  [38464/60000]
# loss: 0.089758  [44864/60000]
# loss: 0.267735  [51264/60000]
# loss: 0.210524  [57664/60000]
# Train Error:
#  Accuracy: 94.1%, Avg loss: 0.002596
#
# Test Error:
#  Accuracy: 89.0%, Avg loss: 0.004986
#
# Epoch 91
# -------------------------------
# loss: 0.164817  [   64/60000]
# loss: 0.107206  [ 6464/60000]
# loss: 0.220012  [12864/60000]
# loss: 0.146347  [19264/60000]
# loss: 0.148564  [25664/60000]
# loss: 0.087282  [32064/60000]
# loss: 0.161808  [38464/60000]
# loss: 0.145499  [44864/60000]
# loss: 0.147101  [51264/60000]
# loss: 0.112242  [57664/60000]
# Train Error:
#  Accuracy: 94.3%, Avg loss: 0.002546
#
# Test Error:
#  Accuracy: 88.6%, Avg loss: 0.005112
#
# Epoch 92
# -------------------------------
# loss: 0.113156  [   64/60000]
# loss: 0.248812  [ 6464/60000]
# loss: 0.130139  [12864/60000]
# loss: 0.264022  [19264/60000]
# loss: 0.072212  [25664/60000]
# loss: 0.209024  [32064/60000]
# loss: 0.146172  [38464/60000]
# loss: 0.241474  [44864/60000]
# loss: 0.133352  [51264/60000]
# loss: 0.198897  [57664/60000]
# Train Error:
#  Accuracy: 94.3%, Avg loss: 0.002540
#
# Test Error:
#  Accuracy: 88.9%, Avg loss: 0.004981
#
# Epoch 93
# -------------------------------
# loss: 0.089903  [   64/60000]
# loss: 0.199386  [ 6464/60000]
# loss: 0.066610  [12864/60000]
# loss: 0.110319  [19264/60000]
# loss: 0.126536  [25664/60000]
# loss: 0.111207  [32064/60000]
# loss: 0.143564  [38464/60000]
# loss: 0.170067  [44864/60000]
# loss: 0.067234  [51264/60000]
# loss: 0.196552  [57664/60000]
# Train Error:
#  Accuracy: 94.4%, Avg loss: 0.002507
#
# Test Error:
#  Accuracy: 89.0%, Avg loss: 0.005043
#
# Epoch 94
# -------------------------------
# loss: 0.190696  [   64/60000]
# loss: 0.212577  [ 6464/60000]
# loss: 0.079305  [12864/60000]
# loss: 0.176271  [19264/60000]
# loss: 0.146776  [25664/60000]
# loss: 0.131321  [32064/60000]
# loss: 0.190602  [38464/60000]
# loss: 0.197650  [44864/60000]
# loss: 0.125753  [51264/60000]
# loss: 0.126098  [57664/60000]
# Train Error:
#  Accuracy: 94.4%, Avg loss: 0.002480
#
# Test Error:
#  Accuracy: 89.2%, Avg loss: 0.005030
#
# Epoch 95
# -------------------------------
# loss: 0.144926  [   64/60000]
# loss: 0.097417  [ 6464/60000]
# loss: 0.103931  [12864/60000]
# loss: 0.033854  [19264/60000]
# loss: 0.188755  [25664/60000]
# loss: 0.199736  [32064/60000]
# loss: 0.180610  [38464/60000]
# loss: 0.143146  [44864/60000]
# loss: 0.134418  [51264/60000]
# loss: 0.179339  [57664/60000]
# Train Error:
#  Accuracy: 94.5%, Avg loss: 0.002445
#
# Test Error:
#  Accuracy: 89.0%, Avg loss: 0.005063
#
# Epoch 96
# -------------------------------
# loss: 0.099940  [   64/60000]
# loss: 0.170988  [ 6464/60000]
# loss: 0.097704  [12864/60000]
# loss: 0.099883  [19264/60000]
# loss: 0.309601  [25664/60000]
# loss: 0.238280  [32064/60000]
# loss: 0.236601  [38464/60000]
# loss: 0.076190  [44864/60000]
# loss: 0.209615  [51264/60000]
# loss: 0.225342  [57664/60000]
# Train Error:
#  Accuracy: 94.6%, Avg loss: 0.002432
#
# Test Error:
#  Accuracy: 89.1%, Avg loss: 0.005178
#
# Epoch 97
# -------------------------------
# loss: 0.144833  [   64/60000]
# loss: 0.103271  [ 6464/60000]
# loss: 0.144667  [12864/60000]
# loss: 0.109415  [19264/60000]
# loss: 0.086421  [25664/60000]
# loss: 0.314438  [32064/60000]
# loss: 0.205778  [38464/60000]
# loss: 0.080964  [44864/60000]
# loss: 0.141636  [51264/60000]
# loss: 0.076335  [57664/60000]
# Train Error:
#  Accuracy: 94.5%, Avg loss: 0.002404
#
# Test Error:
#  Accuracy: 89.3%, Avg loss: 0.004948
#
# Epoch 98
# -------------------------------
# loss: 0.134607  [   64/60000]
# loss: 0.176934  [ 6464/60000]
# loss: 0.257689  [12864/60000]
# loss: 0.226728  [19264/60000]
# loss: 0.124132  [25664/60000]
# loss: 0.172726  [32064/60000]
# loss: 0.132773  [38464/60000]
# loss: 0.066496  [44864/60000]
# loss: 0.121214  [51264/60000]
# loss: 0.108203  [57664/60000]
# Train Error:
#  Accuracy: 94.7%, Avg loss: 0.002358
#
# Test Error:
#  Accuracy: 88.6%, Avg loss: 0.005512
#
# Epoch 99
# -------------------------------
# loss: 0.141612  [   64/60000]
# loss: 0.095038  [ 6464/60000]
# loss: 0.159136  [12864/60000]
# loss: 0.163224  [19264/60000]
# loss: 0.105746  [25664/60000]
# loss: 0.101199  [32064/60000]
# loss: 0.280646  [38464/60000]
# loss: 0.142006  [44864/60000]
# loss: 0.085862  [51264/60000]
# loss: 0.124906  [57664/60000]
# Train Error:
#  Accuracy: 94.8%, Avg loss: 0.002339
#
# Test Error:
#  Accuracy: 89.4%, Avg loss: 0.005065
#
# Epoch 100
# -------------------------------
# loss: 0.145872  [   64/60000]
# loss: 0.078349  [ 6464/60000]
# loss: 0.098433  [12864/60000]
# loss: 0.160878  [19264/60000]
# loss: 0.148682  [25664/60000]
# loss: 0.100482  [32064/60000]
# loss: 0.126098  [38464/60000]
# loss: 0.085632  [44864/60000]
# loss: 0.180292  [51264/60000]
# loss: 0.114802  [57664/60000]
# Train Error:
#  Accuracy: 94.8%, Avg loss: 0.002313
#
# Test Error:
#  Accuracy: 88.2%, Avg loss: 0.005524
#
# Done!

# %%
import matplotlib.pylab as plt

# plot learning curves
plt.figure(1)
plt.plot(range(epochs), train_loss, label='train')
plt.plot(range(epochs), test_loss, label = "test")
plt.xlabel('epochs')
plt.ylabel('cross-entropy loss')
plt.legend()
plt.show()

# %%
# plot learning curves
plt.figure(2)
plt.plot(range(epochs), train_acc, label='train')
plt.plot(range(epochs), test_acc, label = "test")
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend()
plt.show()
